# %%
# best_logistic_model_args=[10000,0.01,False,1e-2]

# %%
def k_fold_tests(k_values):
    for k in k_values:
        print("RUNNING", k, "FOLD ON EACH DATASET")
        run_cross_validations(train_val, k, True, True, True, best_logistic_model_args)

# %%
# # All accuracies 5-fold, 10-fold, 20-fold
# k_fold_tests([5,10,15])
# Out:
# ionosphere -----
# 	Running k_fold on:  ionosphere
# 	Running Logistic Regression
#       Type Average Time (s) Maximum Time (s) Minimum Time (s)
# 0      Fit           0.2358           0.2393           0.2316
# 1  Predict           0.0001           0.0001           0.0001
# 2    Total           0.2359           0.2394           0.2318
#
# 		Accuracy:  0.8490945674044266
#
#
# 	Running Naive Bayes
#
#       Type Average Time (s) Maximum Time (s) Minimum Time (s)
# 0      Fit           0.0079           0.0081           0.0074
# 1  Predict           0.0050           0.0050           0.0049
# 2    Total           0.0129           0.0131           0.0123
#
# 		Accuracy:  0.815010060362173
#
# adult -----
# 	Running k_fold on:  adult
# 	Running Logistic Regression
#       Type Average Time (s) Maximum Time (s) Minimum Time (s)
# 0      Fit         214.7361         277.5891         154.0164
# 1  Predict           0.0070           0.0132           0.0036
# ...
