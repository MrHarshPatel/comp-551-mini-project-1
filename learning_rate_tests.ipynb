# %%
def learning_rates_test(lrs):
    for lr in lrs:
        print("Running with learning rate of ", lr)
        run_cross_validations(train_val,5,use_nb=False,model_args=[10000,lr,False,1e-2,False])

# %%
# Learning Rates using termination 10,000 at 0.01,0.05,0.1,0.2 and 0.3
learning_rates_test([0.01,0.05,0.1,0.2,0.3])
# Out:
# Running with learning rate of  0.01
# ionosphere -----
# 	Running k_fold on:  ionosphere
# 	Running Logistic Regression
#       Type Average Time (s) Maximum Time (s) Minimum Time (s)
# 0      Fit           0.2926           0.3006           0.2803
# 1  Predict           0.0001           0.0002           0.0001
# 2    Total           0.2927           0.3007           0.2804
#
# 		Accuracy:  0.8662374245472837
#
# adult -----
# 	Running k_fold on:  adult
# 	Running Logistic Regression
#       Type Average Time (s) Maximum Time (s) Minimum Time (s)
# 0      Fit         207.6774         211.1532         197.2273
# 1  Predict           0.0039           0.0050           0.0026
# 2    Total         207.6813         211.1571         197.2300
#
# 		Accuracy:  0.672101576250645
#
# thoracic_surgery -----
# 	Running k_fold on:  thoracic_surgery
# 	Running Logistic Regression
#       Type Average Time (s) Maximum Time (s) Minimum Time (s)
# ...
