# %%
def use_epsilons_test(eps):
    for e in eps:
        print("Running with epsilon value of ", e)
        run_cross_validations(train_val,5,use_nb=False,model_args=[10000,0.1,True,e,False])

# %%
# Learning Rates using termination 10,000 at 0.1,0.01,0.001
use_epsilons_test([1e-1,1e-2,1e-3])
# Out:
# Running with epsilon value of  0.1
# ionosphere -----
# 	Running k_fold on:  ionosphere
# 	Running Logistic Regression
#       Type Average Time (s) Maximum Time (s) Minimum Time (s)
# 0      Fit           0.3144           0.3517           0.3005
# 1  Predict           0.0001           0.0002           0.0001
# 2    Total           0.3145           0.3518           0.3008
#
# 		Accuracy:  0.8518309859154929
#
# adult -----
# 	Running k_fold on:  adult
# 	Running Logistic Regression
#       Type Average Time (s) Maximum Time (s) Minimum Time (s)
# 0      Fit         210.2830         213.4973         202.6875
# 1  Predict           0.0043           0.0050           0.0035
# 2    Total         210.2873         213.5014         202.6925
#
# 		Accuracy:  0.6709739351793785
#
# thoracic_surgery -----
# 	Running k_fold on:  thoracic_surgery
# 	Running Logistic Regression
#       Type Average Time (s) Maximum Time (s) Minimum Time (s)
# ...
