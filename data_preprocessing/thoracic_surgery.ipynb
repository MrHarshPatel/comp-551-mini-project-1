# %%
import pandas as pd 
import numpy as np
pd.set_option('display.max_columns', None)

thoracic_data = pd.read_csv('../data/thoracic_surgery.csv')
thoracic_data
# Out:
#     dgn_code  forced_vital_capacity  \
# 0       DGN2                   2.88
# 1       DGN3                   3.40
# 2       DGN3                   2.76
# 3       DGN3                   3.68
# 4       DGN3                   2.44
# 5       DGN3                   2.48
# 6       DGN3                   4.36
# 7       DGN2                   3.19
# 8       DGN3                   3.16
# 9       DGN3                   2.32
# 10      DGN3                   2.56
# 11      DGN3                   4.28
# 12      DGN3                   3.00
# 13      DGN2                   3.98
# 14      DGN3                   1.96
# 15      DGN3                   4.68
# 16      DGN2                   2.21
# 17      DGN2                   2.96
# 18      DGN3                   2.60
# 19      DGN3                   2.88
# 20      DGN3                   4.48
# 21      DGN4                   3.32
# 22      DGN3                   2.36
# 23      DGN3                   3.68
# 24      DGN8                   4.32
# ...
