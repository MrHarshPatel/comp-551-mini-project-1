# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)

credit_card_data = pd.read_csv('../data/credit_card.csv')
credit_card_data = credit_card_data.drop(columns=['ID'])

credit_export = np.array(credit_card_data)
credit_headers = np.array(credit_card_data.columns)

# %store credit_export
# %store credit_headers
# Out:
# Stored 'credit_export' (ndarray)
# Stored 'credit_headers' (ndarray)

# %%
credit_card_data
# Out:
#        LIMIT_BAL_g  SEX_b  EDUCATION_b  MARRIAGE_b  AGE_g  PAY_0_b  PAY_2_b  \
# 0            20000      2            2           1     24        2        2
# 1           120000      2            2           2     26       -1        2
# 2            90000      2            2           2     34        0        0
# 3            50000      2            2           1     37        0        0
# 4            50000      1            2           1     57       -1        0
# 5            50000      1            1           2     37        0        0
# 6           500000      1            1           2     29        0        0
# 7           100000      2            2           2     23        0       -1
# 8           140000      2            3           1     28        0        0
# 9            20000      1            3           2     35       -2       -2
# 10          200000      2            3           2     34        0        0
# ...

# %%
labels = credit_card_data.loc[:,'default_payment_next_month_b']

data_vis = credit_card_data
data_vis = data_vis.drop(columns="default_payment_next_month_b")

col1 = data_vis.loc[: , "PAY_0_b":"PAY_6_b"]
data_vis['pay_mean'] = col1.mean(axis=1)

col2 = data_vis.loc[: , "BILL_AMT1_g":"BILL_AMT6_g"]
data_vis['bill_amt_mean'] = col2.mean(axis=1)

col3 = data_vis.loc[: , "PAY_AMT1_g":"PAY_AMT6_g"]
data_vis['pay_amt_mean'] = col3.mean(axis=1)

# %%
data_vis['default_payment_next_month_b'] = labels
data_vis
# Out:
#        LIMIT_BAL_g  SEX_b  EDUCATION_b  MARRIAGE_b  AGE_g  PAY_0_b  PAY_2_b  \
# 0            20000      2            2           1     24        2        2
# 1           120000      2            2           2     26       -1        2
# 2            90000      2            2           2     34        0        0
# 3            50000      2            2           1     37        0        0
# 4            50000      1            2           1     57       -1        0
# 5            50000      1            1           2     37        0        0
# 6           500000      1            1           2     29        0        0
# 7           100000      2            2           2     23        0       -1
# 8           140000      2            3           1     28        0        0
# 9            20000      1            3           2     35       -2       -2
# 10          200000      2            3           2     34        0        0
# ...

# %%
data_vis_arr = np.array(data_vis)

# %%
classes = ('Default', 'No Default')
y_pos = np.arange(len(classes))
num_above = np.count_nonzero(data_vis_arr[:,-1]==1)
num_below = np.count_nonzero(data_vis_arr[:,-1]==0)
num = [num_above, num_below]

plt.bar(y_pos, num, align='center', alpha=0.5)
plt.xticks(y_pos, classes)
plt.ylabel('Classes')
plt.title('Number of Default Payments and Non-Default Payments')

plt.show()

# %%
credit_limit = data_vis_arr[:, 0] # credit limit  
# pay_mean = data_vis_arr[:, -4] # avg pay   
# bill_amt_mean = data_vis_arr[:, -3] # avg bill amount  

default_next_month = data_vis_arr[:, -1] # credit limit  
y_pos = np.arange(len(credit_limit))


fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.scatter(credit_limit, default_next_month, color='r')
# ax.scatter(pay_mean, default_next_month, color='g')
# ax.scatter(bill_amt_mean, default_next_month, color='b')
# ax.legend(('data', 'line-regression r={}'.format(r_value)), 'best')


ax.set_title('Credit Limit vs. Default Payment Next Month')
ax.set_xlabel('Credit Limit')
ax.set_ylabel('Default Payment Next Month')
# Out:
# Text(0,0.5,'Default Payment Next Month')

# %%
pay_mean = data_vis_arr[:, -4] # avg pay   
default_next_month = data_vis_arr[:, -1] # credit limit  
y_pos = np.arange(len(pay_mean))


fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.scatter(pay_mean, default_next_month, color='r')
# ax.scatter(x3, x4, color='g')
# ax.scatter(x5, x6, color='b')
# ax.legend(('data', 'line-regression r={}'.format(r_value)), 'best')


ax.set_title('Average Pay vs. Default Payment Next Month')
ax.set_xlabel('Average Pay')
ax.set_ylabel('Default Payment Next Month')
# Out:
# Text(0,0.5,'Default Payment Next Month')

# %%
bill_amt_mean = data_vis_arr[:, -3] # avg bill amount  
default_next_month = data_vis_arr[:, -1] # credit limit  
y_pos = np.arange(len(bill_amt_mean))


fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.scatter(bill_amt_mean, default_next_month, color='r')
# ax.scatter(x3, x4, color='g')
# ax.scatter(x5, x6, color='b')
# ax.legend(('data', 'line-regression r={}'.format(r_value)), 'best')


ax.set_title('Average Bill Amount vs. Default Payment Next Month')
ax.set_xlabel('Average Pay')
ax.set_ylabel('Default Payment Next Month')
# Out:
# Text(0,0.5,'Default Payment Next Month')

# %%
pay_amt_mean = data_vis_arr[:, -2] # avg pay   
default_next_month = data_vis_arr[:, -1] # credit limit  
y_pos = np.arange(len(pay_amt_mean))


fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.scatter(pay_amt_mean, default_next_month, color='r')
# ax.scatter(x3, x4, color='g')
# ax.scatter(x5, x6, color='b')
# ax.legend(('data', 'line-regression r={}'.format(r_value)), 'best')


ax.set_title('Average Payment Amount vs. Default Payment Next Month')
ax.set_xlabel('Average Payment')
ax.set_ylabel('Default Payment Next Month')
# Out:
# Text(0,0.5,'Default Payment Next Month')

# %%
age = data_vis_arr[:, 4]    
default_next_month = data_vis_arr[:, -1] # credit limit  
y_pos = np.arange(len(age))


fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.scatter(age, default_next_month, color='r')
# ax.scatter(x3, x4, color='g')
# ax.scatter(x5, x6, color='b')
# ax.legend(('data', 'line-regression r={}'.format(r_value)), 'best')


ax.set_title('Age vs. Default Payment Next Month')
ax.set_xlabel('Age')
ax.set_ylabel('Default Payment Next Month')
# Out:
# Text(0,0.5,'Default Payment Next Month')

# %%
n_groups = 2

female_def = np.count_nonzero(np.logical_and(data_vis_arr[:,-1]==1, data_vis_arr[:,1]==2))
female_no_def = np.count_nonzero(np.logical_and(data_vis_arr[:,-1]==0, data_vis_arr[:,1]==2))
male_def = np.count_nonzero(np.logical_and(data_vis_arr[:,-1]==1, data_vis_arr[:,1]==1))
male_no_def = np.count_nonzero(np.logical_and(data_vis_arr[:,-1]==0, data_vis_arr[:,1]==1))

num_def = (female_def, male_def)
num_no_def = (female_no_def, male_no_def)

# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.8

rects1 = plt.bar(index, num_def, bar_width,
alpha=opacity,
color='b',
label='Default')

rects2 = plt.bar(index + bar_width, num_no_def, bar_width,
alpha=opacity,
color='g',
label='No Default')

plt.xlabel('Sex')
plt.ylabel('Number')
plt.title('Sex vs. Default Next Month')
plt.xticks(index + bar_width, ('Female', 'Male'))
plt.legend()

plt.tight_layout()
plt.show()

# %%
n_groups = 4

#graduate studies
grad_def = np.count_nonzero(np.logical_and(data_vis_arr[:,-1]==1, data_vis_arr[:,2]==1))
grad_no_def = np.count_nonzero(np.logical_and(data_vis_arr[:,-1]==0, data_vis_arr[:,2]==1))

# uni
uni_def = np.count_nonzero(np.logical_and(data_vis_arr[:,-1]==1, data_vis_arr[:,2]==2))
uni_no_def = np.count_nonzero(np.logical_and(data_vis_arr[:,-1]==0, data_vis_arr[:,2]==2))

#highschool
hs_def = np.count_nonzero(np.logical_and(data_vis_arr[:,-1]==1, data_vis_arr[:,2]==3))
hs_no_def = np.count_nonzero(np.logical_and(data_vis_arr[:,-1]==0, data_vis_arr[:,2]==3))

#other
other_def = np.count_nonzero(np.logical_and(data_vis_arr[:,-1]==1, data_vis_arr[:,2]==4))
other_no_def = np.count_nonzero(np.logical_and(data_vis_arr[:,-1]==0, data_vis_arr[:,2]==4))

num_def = (grad_def, uni_def, hs_def, other_def)
num_no_def = (grad_no_def, uni_no_def, hs_no_def, other_no_def)

# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.8

rects1 = plt.bar(index, num_def, bar_width,
alpha=opacity,
color='b',
label='Default')

rects2 = plt.bar(index + bar_width, num_no_def, bar_width,
alpha=opacity,
color='g',
label='No Default')

plt.xlabel('Education Level')
plt.ylabel('Number')
plt.title('Education Level vs. Default Next Month')
plt.xticks(index + bar_width, ('Graduate Studies', 'University', 'High School', 'Other'))
plt.legend()

plt.tight_layout()
plt.show()

# %%
n_groups = 3

# married
married_def = np.count_nonzero(np.logical_and(data_vis_arr[:,-1]==1, data_vis_arr[:,3]==1))
married_no_def = np.count_nonzero(np.logical_and(data_vis_arr[:,-1]==0, data_vis_arr[:,3]==1))

# single
single_def = np.count_nonzero(np.logical_and(data_vis_arr[:,-1]==1, data_vis_arr[:,3]==2))
single_no_def = np.count_nonzero(np.logical_and(data_vis_arr[:,-1]==0, data_vis_arr[:,3]==2))

#other
other_def = np.count_nonzero(np.logical_and(data_vis_arr[:,-1]==1, data_vis_arr[:,3]==3))
other_no_def = np.count_nonzero(np.logical_and(data_vis_arr[:,-1]==0, data_vis_arr[:,3]==3))

num_def = (married_def, single_def, other_def)
num_no_def = (married_no_def, single_no_def, other_no_def)

# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.8

rects1 = plt.bar(index, num_def, bar_width,
alpha=opacity,
color='b',
label='Default')

rects2 = plt.bar(index + bar_width, num_no_def, bar_width,
alpha=opacity,
color='g',
label='No Default')

plt.xlabel('Marital Status')
plt.ylabel('Number')
plt.title('Marital Status vs. Default Next Month')
plt.xticks(index + bar_width, ('Married', 'Single', 'Other'))
plt.legend()

plt.tight_layout()
plt.show()
